# %%
import pandas as pd

df = pd.read_csv('data/omniart_v3_datadump.csv')

# %%
df
# Out:
#                                            id  \
# 0        4ee8e28a-9df1-4af4-b9cc-c78a761c6b15
# 1        80fa7733-e6c6-4398-b20a-eff2c5bef278
# 2        17e45c05-c224-4e18-9885-03a1beae62ea
# 3        093cf203-734c-4828-bc94-391907932fee
# 4        fc0e311f-d85f-418c-b347-d5a9e0b81e8f
# ...                                       ...
# 1946268  1983f2b4-c5ac-41c4-a12c-5b74e43516ae
# 1946269  f29b7d22-c846-4995-8ed6-cb4a8e0afbc4
# 1946270  bec04d30-72ba-4327-b9e7-82985d4887df
# 1946271  df61b532-c7e7-4ff8-95c7-b9a5c4c8e5c0
# 1946272  a82e63b6-b396-407f-95d9-ec4e3442db2c
#
#                                               artwork_name  \
# 0                                                   70 amx
# 1                                  monument of pope leo xi
# 2                                     crucifixion (detail)
# 3                                                    faith
# 4                                                lamp post
# ...

# %%
df.columns
# Out:
# Index(['id', 'artwork_name', 'artist_full_name', 'artist_first_name',
#        'artist_last_name', 'creation_year', 'century', 'source_url',
#        'image_url', 'collection_origins', 'artwork_type', 'school',
#        'original_id_in_collection', 'created_at', 'last_modified', 'omni_id',
#        'created_by_id', 'general_type', 'geocoded', 'color_pallete',
#        'dominant_color', 'palette_count'],
#       dtype='object')

# %%
df[df.general_type == 'painting' ]
# Out:
#                                            id  \
# 0        4ee8e28a-9df1-4af4-b9cc-c78a761c6b15
# 2        17e45c05-c224-4e18-9885-03a1beae62ea
# 3        093cf203-734c-4828-bc94-391907932fee
# 4        fc0e311f-d85f-418c-b347-d5a9e0b81e8f
# 9        50dc528f-a8f4-4501-9134-c7402aa6e73a
# ...                                       ...
# 1942923  307446d0-73b3-47c5-86a8-9d6a5a9bb3bc
# 1942924  5f70e5f8-ab1b-4ab2-81a7-03767835fa9d
# 1942928  ba1bb610-70d6-4547-8259-add8f9419eae
# 1942934  c27640f7-3f50-4e8f-b8c1-aa43d0bc4ac1
# 1946272  a82e63b6-b396-407f-95d9-ec4e3442db2c
#
#                                               artwork_name  \
# 0                                                   70 amx
# 2                                     crucifixion (detail)
# 3                                                    faith
# 4                                                lamp post
# 9                                    the one that got away
# ...

# %%
df.artist_full_name.value_counts()
# Out:
# arkyves arkyves               316969
# unknown                       179985
# brown, robert - m.a., ph.d      7110
# ravenstein, ernst georg.        5820
# ollier, edmund.                 5368
#                                ...
# romyvdhel-art                      1
# chilimonster77                     1
# khemicalkitten                     1
# rmethric55                         1
# beardsley, d. b.                   1
# Name: artist_full_name, Length: 100398, dtype: int64

# %%
df.artwork_type.value_counts()[:50]
# Out:
# photo                        944425
# image                        291507
# painting                     223472
# print                         53618
# emblem pictura                32052
# drawings                      26407
# photograph                    24797
# unknown                       21209
# textiles                      21180
# ceramics                      19979
# metalwork                     17906
# portrait                      14969
# landscape                     14969
# abstract                      14965
# genre painting                14899
# sculpture                     13935
# book illustration             12376
# ursicula                      11905
# periodical image              10755
# design                        10050
# manuscript illumination        9740
# religious painting             8809
# cityscape                      6885
# glass                          6762
# sketch and study               5613
# figurative                     5138
# ...
